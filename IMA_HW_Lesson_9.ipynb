# %% [markdown]
# ### 9 Исследовать функцию на условный экстремум

# %% [markdown]
# #### 9.1 $U = 3 - 8x + 6y$ ,  если  $x^2 + y^2 = 36 $

# %% [markdown]
# #### Необходимые условия

# %% [markdown]
# #### $x^2 + y^2 = 36 => x^2 + y^2 - 36 = 0 $

# %% [markdown]
# #### $L(\lambda, x, y) = 3 - 8x + 6y + \lambda(x^2 + y^2 - 36)$

# %% [markdown]
# $ \begin{equation*}
#  .
#  \begin{cases}
#    L^\prime _x = -8 + 2x\lambda = 0 \\
#    L^\prime _y =   6 + 2y\lambda = 0 \\
#    L^\prime _{\lambda} = x^2 + y^2 - 36 = 0
#  \end{cases}
#  => \begin{cases}
#    x = \frac{4}{\lambda} \\
#    y = \frac{-3}{\lambda} \\
#    (\frac{4}{\lambda})^2 + (\frac{-3}{\lambda})^2 - 36 = 0
#  \end{cases}
#   => \begin{cases}
#    x = \frac{4}{\lambda} \\
#    y = \frac{-3}{\lambda} \\
#    \frac{16}{\lambda^2} + \frac{9}{\lambda^2} - 36 = 0
#  \end{cases}
#   => \begin{cases}
#    x = \frac{4}{\lambda} \\
#    y = \frac{-3}{\lambda} \\
#    25 - 36\lambda^2 = 0
#  \end{cases}
#  => \begin{cases}
#    x = \frac{24}{5}, x = -\frac{24}{5} \\
#    y = -\frac{18}{5}, y = \frac{18}{5} \\
#    \lambda = \frac{5}{6}, \lambda = -\frac{5}{6}
#  \end{cases}
#  \end{equation*}
#  $

# %% [markdown]
# ## $ \left ( \frac{5}{6}, \frac{24}{5}, -\frac{18}{5} \right), \qquad \left (-\frac{5}{6}, -\frac{24}{5}, \frac{18}{5} \right)$

# %% [markdown]
# #### Достаточные условия

# %% [markdown]
# $ L'^\prime _{xx} = 2\lambda ,\qquad   L'^\prime _{yy} = 2\lambda ,\qquad   L'^\prime _{\lambda\lambda} = 0 $

# %% [markdown]
# $ L'^\prime _{xy} = 0 ,\qquad   L'^\prime _{x\lambda} = 2x ,\qquad   L'^\prime _{y\lambda} = 2y $

# %% [markdown]
# $ \begin{vmatrix} 0 & 2x & 2y \\ 2x & 2\lambda & 0 \\ 2y & 0 & 2\lambda \end{vmatrix} => \qquad $ $ 0 \begin{vmatrix} 2\lambda & 0 \\ 0 & 2\lambda \end{vmatrix}- 2x \begin{vmatrix} 2x & 0 \\ 2y & 2\lambda \end{vmatrix} + 2y\begin{vmatrix} 2x & 2\lambda\\ 2y & 0 \end{vmatrix}\qquad = 0  - 2x(4x\lambda - 0) + 2y(0 -4y\lambda) = -8\lambda(x^2 + y^2)$

# %% [markdown]
# ## $ \left ( \frac{5}{6}, \frac{24}{5}, -\frac{18}{5} \right)-min, \qquad \left (-\frac{5}{6}, -\frac{24}{5}, \frac{18}{5} \right) - max$

# %% [markdown]
# #### 9.2 $U = 2x^2 + 12xy + 32y^2 + 15$ ,  если  $x^2 + 16y^2 = 64 $

# %% [markdown]
# #### $x^2 + 16y^2 = 64 =>$  $x^2 + 16y^2 - 64 = 0$

# %% [markdown]
# #### $L(\lambda, x, y) = 2x^2 + 12xy + 32y^2 + 15 + \lambda(x^2 + 16y^2 - 64)$

# %% [markdown]
# $ \begin{equation*}
#  .
#  \begin{cases}
#    L^\prime _x = 4x +12y + 2x\lambda = 0 \\
#    L^\prime _y =  12x + 64y + 32y\lambda = 0 \\
#    L^\prime _{\lambda} = x^2 + 16y^2 - 64 = 0
#  \end{cases}
#  => \begin{cases}
#    2x +6y + x\lambda = 0 \\
#    3x + 16y + 8y\lambda = 0 \\
#    x^2 + 16y^2 - 64 = 0
#  \end{cases} => \begin{cases}
#     x(2+\lambda) = - 6y\\
#    y = -\frac{3x}{8(2+\lambda)} \\
#    x^2 + 16y^2 - 64 = 0
#  \end{cases} => \begin{cases}
#     x = -\frac{6y}{(2+\lambda)}\\
#    y = -\frac{3x}{8(2+\lambda)} \\
#    x^2 + 16y^2 - 64 = 0
#  \end{cases}=>
#  \end{equation*}
#  $

# %% [markdown]
# $ \begin{equation*}
#  => \begin{cases}
#     x = -\frac{6y}{(2+\lambda)}\\
#    -\frac{18y}{(2+\lambda)} + \frac{16y(2+\lambda)}{(2+\lambda)} + \frac{8y\lambda(2+\lambda)}{(2+\lambda)} = 0 \\
#    x^2 + 16y^2 - 64 = 0
#  \end{cases}=>\begin{cases}
#     x = -\frac{6y}{(2+\lambda)}\\
#    -18y + 16y(2+\lambda) + 8y\lambda(2+\lambda) = 0 \\
#    x^2 + 16y^2 - 64 = 0
#  \end{cases}=>\begin{cases}
#     x = -\frac{6y}{(2+\lambda)}\\
#    -14y + 32y\lambda + 8y\lambda^2 = 0 \\
#    x^2 + 16y^2 - 64 = 0
#  \end{cases}=> \begin{cases}
#     x = -\frac{6y}{(2+\lambda)}\\
#     y = 0 \\
#    x^2 + 16y^2 - 64 = 0
#  \end{cases}
#  \end{equation*}
#  $ система не имеет решения через метод множителей Лагранжа

# %% [markdown]
# ### попытка решить через подстановку

# %% [markdown]
# #### $U = 2x^2 + 12x*( \frac{(64 - x^2)}{16} )^{\frac{1}{2}} + 32 * \frac{(64 - x^2)}{16}  + 15 = 2x^2 + 12x*( \frac{(64 - x^2)}{16} )^{\frac{1}{2}} + 2 * (64 - x^2)  + 15 = 12x*( \frac{(64 - x^2)}{16} )^{\frac{1}{2}} +143 $

# %% [markdown]
# #### $U =  3x*(64 - x^2)^{\frac{1}{2}} + 143 $

# %% [markdown]
# #### $U' =  (3x*(64 - x^2)^{\frac{1}{2}} + 143)^\prime = (3x*(64 - x^2)^{\frac{1}{2}})^\prime = -3\frac{x^2}{\sqrt{64-x^2}} + 3\sqrt{64-x^2} = 0 => -3\frac{x^2}{\sqrt{64-x^2}} + 3\frac{\sqrt{64-x^2}\sqrt{64-x^2}}{\sqrt{64-x^2}} = 0 => \\ -3x^2 + 3(64-x^2)=0 => 6x^2  = 192 => x^2 = 32 => x_1 = 4\sqrt{2}, x_2 = -4\sqrt{2}$

# %% [markdown]
# $U'' = (x^2 - 32)' = 2x =>  x_1 = 8\sqrt{2} - min, x_2 = -8\sqrt{2} -max $

# %% [markdown]
# ####  $x^2 + 16y^2 = 64 $

# %% [markdown]
# ####  $(4\sqrt{2})^2 + 16y^2 = 64 => 32 + 16y^2 = 64 => y^2 = 2 => y=\sqrt{2},y=-\sqrt{2} $

# %% [markdown]
# $M_1(4\sqrt{2},\sqrt{2}), M_2(4\sqrt{2},-\sqrt{2}), M_3(-4\sqrt{2},\sqrt{2}), M_4(-4\sqrt{2},-\sqrt{2}) $

# %% [markdown]
# #### 9.3 Найти производную функции $U = e^{x^2 + y^2 + z^2}$ по направлению вектора   $\overrightarrow{с}(-9,8,-12)$  в точку $M(8;-12;9)$

# %% [markdown]
# ### $U'_x = (e^{x^2 + y^2 + z^2})^\prime_x = 2xe^{x^2 + y^2 + z^2} => U'_x(8;-12;9) = 16e^{8^2 + (-12)^2 + 9^2} = 16e^{289} $

# %% [markdown]
# ### $U'_y = (e^{x^2 + y^2 + z^2})^\prime _y = 2ye^{x^2 + y^2 + z^2} => U'_y(8;-12;9) = -24e^{289} $

# %% [markdown]
# ### $U'_z = (e^{x^2 + y^2 + z^2})^\prime_z = 2ze^{x^2 + y^2 + z^2} => U'_z(8;-12;9) = 18e^{289}$

# %% [markdown]
# ### $(16e^{289},-24e^{289}, 18e^{289} )$

# %% [markdown]
# $|\overrightarrow{с}| = \sqrt{x^2_0 + y^2_0 + z^2_0} = \sqrt{(-9)^2 + 8^2 + (-12)^2} = \sqrt{81 + 64 + 144} = 17$

# %% [markdown]
# ### $\overrightarrow{с}_0 = \frac{\overrightarrow{с}}{|\overrightarrow{с}|} = \left( \frac{-9}{17},\frac{8}{17},\frac{-12}{17}
# \right)$

# %% [markdown]
# ### $\overrightarrow{с}_0 = \frac{\overrightarrow{с}}{|\overrightarrow{с}|} = (\frac{-9}{17},\frac{8}{17},\frac{-12}{17})$

# %% [markdown]
# ### $U^\prime_c(M) = \frac{\overrightarrow{с}}{|\overrightarrow{с}|}(M) = -\frac{9}{17}16e^{289}-\frac{8}{17}24e^{289}-\frac{12}{17}18e^{289} = -\frac{144}{17}e^{289}-\frac{192}{17}e^{289}-\frac{216}{17}e^{289} = -\frac{552}{17}e^{289}$

# %% [markdown]
# #### 9.4 Найти производную функции $U = e^{x^2 + y^2 + z^2}$ по направлению вектора   $\overrightarrow{d}(4,-13,-16)$  в точку $L(-16;4;-13)$

# %% [markdown]
# ### $U'_x = (e^{x^2 + y^2 + z^2})^\prime_x = 2xe^{x^2 + y^2 + z^2} => U'_x(-16;4;-13) = -32e^{(-16)^2 + (4)^2 + (-13)^2} = -32e^{289} $

# %% [markdown]
# ### $U'_y = (e^{x^2 + y^2 + z^2})^\prime _y = 2ye^{x^2 + y^2 + z^2} => U'_y(-16;4;-13) = 8e^{289} $

# %% [markdown]
# ### $U'_z = (e^{x^2 + y^2 + z^2})^\prime_z = 2ze^{x^2 + y^2 + z^2} => U'_z(-16;4;-13) = -26e^{289}$

# %% [markdown]
# ### $(-32e^{289},8e^{289}, -26e^{289} )$

# %% [markdown]
# $|\overrightarrow{d}| = \sqrt{x^2_0 + y^2_0 + z^2_0} = \sqrt{(4)^2 + (-13)^2 + (-16)^2} = \sqrt{16 + 169 + 256} = 21$

# %% [markdown]
# ### $\overrightarrow{d}_0 = \frac{\overrightarrow{d}}{|\overrightarrow{d}|} = \left( \frac{4}{21},\frac{-13}{21},\frac{-16}{21}
# \right)$

# %% [markdown]
# ### $U^\prime_d(M) = \frac{\overrightarrow{d}}{|\overrightarrow{d}|}(M) = -\frac{4}{21}32e^{289}-\frac{13}{21}8e^{289}+\frac{16}{21}26e^{289} = -\frac{128}{21}e^{289}-\frac{104}{21}e^{289}+\frac{416}{21}e^{289} = \frac{184}{21}e^{289}$
