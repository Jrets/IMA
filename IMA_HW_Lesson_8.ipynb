# %% [markdown]
# ### 8. Домашнее задание по теме «Производные функций нескольких переменных».

# %% [markdown]
# #### 8.1  Найти область определения функции.

# %% [markdown]
# ### $z = \sqrt{1 - x^3} + \ln{(y^2 - 1)} $ <br> $ - \infty < x \leq 1,  - \infty < y < -1 , 1 < y < + \infty $

# %% [markdown]
# #### 8.2 Найти производные 1-го порядка функции.

# %% [markdown]
# ### $z = (1 + \frac{\ln{x}}{\ln{y}})^3 $ <br> $z^\prime _x = ((1 + \frac{\ln{x}}{\ln{y}})^3)^\prime _x = 3(1 + \frac{\ln{x}}{\ln{y}})^2 ( \frac{\ln{x}}{\ln{y}})^\prime _x =3(1 + \frac{\ln{x}}{\ln{y}})^2 \frac{1}{x\ln{y}}   $  <br> $z^\prime _y =((1 + \frac{\ln{x}}{\ln{y}})^3) ^\prime _y = 3(1 + \frac{\ln{x}}{\ln{y}})^2 ( \frac{\ln{x}}{\ln{y}})^\prime _y =3(1 + \frac{\ln{x}}{\ln{y}})^2 (- \frac{y\ln{x}}{\ln^2{y}}) $

# %% [markdown]
# #### 8.3 Найти полный дифференциал функции в точке (1;1)

# %% [markdown]
# ### $z = \sqrt{2xy + \cos{\frac{x}{y}}} $ <br> $dz = (\sqrt{2xy + \cos{\frac{x}{y}}})^ \prime _x dx + (\sqrt{2xy + \cos{\frac{x}{y}}})^ \prime _y dy= ((2xy + \cos{\frac{x}{y}})^\frac{1}{2} )^ \prime _x dx + ((2xy + \cos{\frac{x}{y}})^\frac{1}{2} )^ \prime _y dy =$ <br> $ \frac{1}{2* \sqrt{2xy + \cos{\frac{x}{y}}}} (2y - \frac{1}{y}\sin{\frac{x}{y}})dx +  \frac{1}{2* \sqrt{2xy + \cos{\frac{x}{y}}}} (2x + x \frac{\sin{\frac{x}{y}}}{y^2})dy => dz(1;1) = \frac{1}{\sqrt{3}}dx +  \frac{1}{\sqrt{3}}dy $

# %% [markdown]
# #### 8.4  Исследовать на экстремум функцию

# %% [markdown]
# ### $z = x^2 + xy + y^2 - 6x - 9y$

# %% [markdown]
# ### $z^\prime _x = 2x + y -6$ <br> $z^\prime _y = x + 2y - 9$

# %% [markdown]
# #### необходимое условие для существования экстремума

# %% [markdown]
# $ \begin{equation*}
#  .
#  \begin{cases}
#    2x + y - 6 =0 \\
#    x + 2y - 9 = 0
#  \end{cases}
# \end{equation*} =>
#  \begin{cases}
#    y= 6 - 2x \\
#    x + 2(6-2x) - 9 = 0
#  \end{cases} =>
#  \begin{cases}
#    y= 6 - 2x \\
#    x = 1
#  \end{cases} =>\begin{cases}
#    y= 4 \\
#    x = 1
#  \end{cases} $

# %% [markdown]
# #### достаточное условие экстремума функции двух переменных

# %% [markdown]
# ### $z'^\prime _{xx} = (2x + y -6)'_x = 2$<br> $z'^\prime _{xy} = (2x + y -6)'_y = 1 $<br> $z'^\prime _{yy} = (x + 2y - 9)'_y = 2$

# %% [markdown]
# #### $AC - B^2 => 2*2-1^2 = 3 > 0, A > 0 $
# функция имеет экстремум - локальный минимум

# %% [markdown]
# #### $z_{min}(1;4) = 1^2 + 1*4 + 4^2 - 6*1 - 9*4 = 1 + 4 + 16 - 6 - 36 = -21$
